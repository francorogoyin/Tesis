# %%
# Librerías.
import pandas as pd
import Funciones as f
import unidecode
from docx import Document
from docx.shared import Inches
import os
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# %%capture
# %run "19. CO y CT.ipynb"

# %%
# %%capture
# Diccionario con ítems.
Items = {
   3: {
       "Numero_Item": 3,
       "Titulo": "Aborto debe ser ilegal",
       "Tipo": "Conservador"
   },
   4: {
       "Numero_Item": 4,
       "Titulo": "Prohibir docentes homosexuales",
       "Tipo": "Conservador"
   },
   5: {
       "Numero_Item": 5,
       "Titulo": "Consultas populares vinculantes",
       "Tipo": "Progresista"
   },
   6: {
       "Numero_Item": 6,
       "Titulo": "Jubilación pública",
       "Tipo": "Progresista"
   },
   7: {
       "Numero_Item": 7,
       "Titulo": "Preferencia por gobiernos militares",
       "Tipo": "Conservador"
   },
   8: {
       "Numero_Item": 8,
       "Titulo": "Exclusividad de los padres en educación sexual",
       "Tipo": "Conservador"
   },
   9: {
       "Numero_Item": 9,
       "Titulo": "Servicios públicos estatales",
       "Tipo": "Progresista"
   },
   10: {
       "Numero_Item": 10,
       "Titulo": "Priorizar seguridad sobre otras áreas",
       "Tipo": "Conservador"
   },
   11: {
       "Numero_Item": 11,
       "Titulo": "Campañas sobre consumo responsable",
       "Tipo": "Progresista"
   },
   16: {
       "Numero_Item": 16,
       "Titulo": "Autogobierno indígena",
       "Tipo": "Progresista"
   },
   19: {
       "Numero_Item": 19,
       "Titulo": "Rechazo a educación sexual",
       "Tipo": "Conservador"
   },
   20: {
       "Numero_Item": 20,
       "Titulo": "Ingreso mínimo para niños",
       "Tipo": "Progresista"
   },
   22: {
       "Numero_Item": 22,
       "Titulo": "Sostenimiento estatal de la Iglesia Católica",
       "Tipo": "Conservador"
   },
   23: {
       "Numero_Item": 23,
       "Titulo": "Restricción a inmigrantes",
       "Tipo": "Conservador"
   },
   24: {
       "Numero_Item": 24,
       "Titulo": "Justificación de piquetes y cortes",
       "Tipo": "Progresista"
   },
   25: {
       "Numero_Item": 25,
       "Titulo": "Evitar concentración mediática",
       "Tipo": "Progresista"
   },
   27: {
       "Numero_Item": 27,
       "Titulo": "Aumento del gasto social en crisis",
       "Tipo": "Progresista"
   },
   28: {
       "Numero_Item": 28,
       "Titulo": "La tierra para quien la trabaja",
       "Tipo": "Progresista"
   },
   29: {
       "Numero_Item": 29,
       "Titulo": "Privatizar empresas públicas",
       "Tipo": "Conservador"
   },
   30: {
       "Numero_Item": 30,
       "Titulo": "No usar medios estatales para propaganda",
       "Tipo": "Conservador"
   }
}

# %%
# Filtrar ítems conservadores.
Items_Conservadores = {
    Clave: Valor for Clave, Valor in Items.items()
    if Valor['Tipo'] == 'Conservador'
}

# Filtrar ítems progresistas.
Items_Progresistas = {
    Clave: Valor for Clave, Valor in Items.items()
    if Valor['Tipo'] == 'Progresista'
}

# %%
# %%capture
# Crear los boxplots de IP sin asociar.

for Nombre_df, df in dfs_Finales.items():
    f.Crear_Boxplots_Items(df, Items, Tipo_Columna='IP_Respuesta', Nombre_Df=Nombre_df)

# %%
# Crear los boxplots de CO Pro y Con para candidatos de izquierda.

for Nombre_df, df in dfs_Finales.items():
    f.Crear_Boxplots_Items(df, Items_Progresistas, Tipo_Columna='CO_Pro_Izq', Nombre_Df=Nombre_df)
    f.Crear_Boxplots_Items(df, Items_Conservadores, Tipo_Columna='CO_Con_Izq', Nombre_Df=Nombre_df)

# %%
# Crear los boxplots de CO Pro y Con para candidatos de derecha.

for Nombre_df, df in dfs_Finales.items():
    f.Crear_Boxplots_Items(df, Items_Progresistas, Tipo_Columna='CO_Pro_Der', Nombre_Df=Nombre_df)
    f.Crear_Boxplots_Items(df, Items_Conservadores, Tipo_Columna='CO_Con_Der', Nombre_Df=Nombre_df)

# %%
# Crear los boxplots de CT Pro y Con para candidatos de izquierda.

for Nombre_df, df in dfs_Finales.items():
    f.Crear_Boxplots_Items(df, Items_Progresistas, Tipo_Columna='CT_Pro_Izq', Nombre_Df=Nombre_df)
    f.Crear_Boxplots_Items(df, Items_Conservadores, Tipo_Columna='CT_Con_Izq', Nombre_Df=Nombre_df)

# %%
# Crear los boxplots de CT Pro y Con para candidatos de derecha.
# %%capture
for Nombre_df, df in dfs_Finales.items():
    f.Crear_Boxplots_Items(df, Items_Progresistas, Tipo_Columna='CT_Pro_Der', Nombre_Df=Nombre_df)
    f.Crear_Boxplots_Items(df, Items_Conservadores, Tipo_Columna='CT_Con_Der', Nombre_Df=Nombre_df)
